# %%
import pandas as pd

data = pd.read_csv('/Users/mac/Desktop/DoneDeal WebScraping/DoneDealCars.csv')
print(data.head())

popular_car_brands = data['CarBrand'].value_counts()
print(popular_car_brands)

N = 5 
top_n_car_brands = popular_car_brands.head(N)
print("Top", N, "popular car brands:")
print(top_n_car_brands)
# Out:
#                                                Title  Price  Year  \
# 0              Mercedes-Benz GLC-Class Glc200d Coupe  67900  2021
# 1                               Volkswagen Golf 2015  12000  2015
# 2  2021 BMW 530e xDrive G30 LCI M Sport M Performanc  55990  2021
# 3       2010 RENAULT FLUENCE   NCT + TAX  !    €3750   3750  2010
# 4                    2009 RENAULT CLIO      ESTATE !   3950  2009
#
#                       Engine     Miles DayPosted       CarBrand
# 0                 2.0 Diesel   22340.0   56 days  Mercedes-Benz
# 1                 1.6 Diesel  192000.0   8 hours     Volkswagen
# 2  2.0 Petrol Plug-in Hybrid   35000.0    3 days            BMW
# 3                 1.5 Diesel  289681.2     0 min        Renault
# 4                 1.5 Diesel  193120.8     0 min        Renault
# Volkswagen        2480
# Audi              2347
# BMW               2241
# Ford              2197
# Toyota            1656
# Nissan            1643
# Mercedes-Benz     1435
# ...
